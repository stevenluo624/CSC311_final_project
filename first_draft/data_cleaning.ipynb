# %% [markdown]
# # Clean Dataset and Feature Engineering

# %% [markdown]
# ## Import

# %%
import pandas as pd

# %%
df = pd.read_csv('~/Desktop/CSC311/Project/project_proposal/training_data_clean.csv')
